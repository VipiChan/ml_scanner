# %% [markdown]
# # 00 — Data smoke
#
# Coverage, universe, and MTF alignment via `ml_scan.ops`.

# %%
from ml_scan.config import load_settings
from ml_scan import ops
settings = load_settings()
print(settings.timescale.db, settings.timescale.port)
ops.coverage(settings, symbols='RELIANCE')
