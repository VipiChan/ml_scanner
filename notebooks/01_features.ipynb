# %% [markdown]
# # 01 — Features
#
# Hourly TA, HTF join, labels, QC.

# %%
from pathlib import Path
from ml_scan.config import load_settings
from ml_scan import ops
settings = load_settings()
root = Path('data/artifacts')
print('use user_command.ipynb M09–M12 cells or:')
print('ops.features_hourly / features_mtf / features_label / features_qc')
