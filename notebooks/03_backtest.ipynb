# %% [markdown]
# # 03 — Backtest
#
# Scan history, event-driven engine, Plotly equity.

# %%
from ml_scan.reporting.charts import equity_figure
from ml_scan import ops
print('ops.backtest_run / write_report — see user_command.ipynb M20–M22')
